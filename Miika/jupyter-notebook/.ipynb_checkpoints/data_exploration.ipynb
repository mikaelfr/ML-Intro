# %% [markdown]
# PROBLEM 1

# %% [markdown]
# Task A

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

npf = pd.read_csv('npf_train.csv')

# %% [markdown]
# Task B

# %%
npf = npf.set_index("date")
## Tell that "class4" is categorical variable. (R does this automatically.) npf["class4"] = npf["class4"].astype("category")
npf["class4"] = npf["class4"].astype("category")
npf = npf.drop("id",axis=1)

npf
# Out:
#               class4  partlybad  CO2168.mean  CO2168.std  CO2336.mean  \
# date
# 2000-01-01  nonevent      False   384.462000    2.284996   384.164462
# 2000-01-20  nonevent      False   374.884615    0.415185   374.703333
# 2000-01-23  nonevent      False   373.496585    0.189497   373.382593
# 2000-02-17  nonevent      False   378.600367    1.934180   378.464862
# 2000-03-25        Ib      False   373.128684    1.096617   372.980000
# ...              ...        ...          ...         ...          ...
# 2011-08-14  nonevent      False   377.541538    6.391551   377.802756
# 2011-08-16  nonevent      False   381.016623    4.411571   381.030844
# 2011-08-18  nonevent      False   386.687895   12.065627   386.284079
# 2011-08-21  nonevent      False   379.279128   12.045785   379.363087
# 2011-08-22  nonevent      False   384.443758    6.413297   384.364392
#
#             CO2336.std  CO242.mean  CO242.std  CO2504.mean  CO2504.std  ...  \
# date                                                                    ...
# 2000-01-01    2.135062  385.274688   2.211695   383.885077    1.955198  ...
# 2000-01-20    0.385179  375.621266   0.665720   374.674177    0.435480  ...
# 2000-01-23    0.172958  373.961481   0.235107   373.275062    0.165500  ...
# 2000-02-17    1.946536  379.785872   2.865022   378.316909    1.983430  ...
# 2000-03-25    1.047750  373.701830   1.259198   372.910000    1.004164  ...
# ...                ...         ...        ...          ...         ...  ...
# 2011-08-14    6.187754  380.131355   8.036365   377.507244    5.398886  ...
# 2011-08-16    4.062115  382.901742   5.061991   381.072078    3.840630  ...
# 2011-08-18   11.751004  392.981111  14.968791   386.336908   11.457833  ...
# 2011-08-21   11.533353  381.268591  14.043508   379.163200   10.932955  ...
# 2011-08-22    5.781036  386.384762   7.663215   384.186892    5.506259  ...
#
#             T672.mean  T672.std   T84.mean   T84.std  UV_A.mean   UV_A.std  \
# date
# 2000-01-01 -13.016471  0.525698 -12.422972  0.376324   1.635563   0.856948
# 2000-01-20  -8.997430  0.373927  -8.351043  0.575679   1.441109   0.741088
# 2000-01-23 -10.224472  0.965988  -9.651155  1.238891   2.677545   1.261612
# 2000-02-17  -1.535183  0.122651  -0.829524  0.134191   2.261805   1.345651
# 2000-03-25  -2.095641  1.695622  -1.095864  2.090111  12.906779   7.022300
# ...               ...       ...        ...       ...        ...        ...
# 2011-08-14  16.470062  2.142789  17.077060  2.779125  16.129744  12.203500
# 2011-08-16  16.319361  1.089563  17.268471  1.308728   8.688739   8.320799
# 2011-08-18  13.315270  0.511146  13.781909  0.838839   7.375727   5.115708
# 2011-08-21  14.421092  1.696894  15.094141  1.745526   8.099394   5.851942
# 2011-08-22  15.049728  0.969001  16.076217  1.197644  11.665070  10.062797
#
#             UV_B.mean  UV_B.std   CS.mean    CS.std
# date
# 2000-01-01   0.026438  0.014617  0.003374  0.000733
# 2000-01-20   0.022649  0.012479  0.001501  0.000572
# 2000-01-23   0.044759  0.023748  0.000764  0.000048
# 2000-02-17   0.030893  0.021903  0.002038  0.000751
# 2000-03-25   0.333523  0.239981  0.000662  0.000210
# ...               ...       ...       ...       ...
# 2011-08-14   0.786032  0.696306  0.002360  0.000253
# 2011-08-16   0.464422  0.496816  0.002423  0.000425
# 2011-08-18   0.366155  0.316015  0.001993  0.000391
# 2011-08-21   0.416961  0.363890  0.003484  0.000457
# 2011-08-22   0.622831  0.595032  0.004782  0.001082
#
# [458 rows x 102 columns]

# %% [markdown]
# Task C

# %% [markdown]
# i)

# %%
npf.describe()
npf = npf.drop("partlybad",axis=1)
# Out:
#        CO2168.mean  CO2168.std  CO2336.mean  CO2336.std  CO242.mean  \
# count   458.000000  458.000000   458.000000  458.000000  458.000000
# mean    380.996307    3.509202   381.014152    3.295570  381.906526
# std      10.897068    3.433711    10.878318    3.192464   10.482752
# min     356.526871    0.053968   356.796486    0.048990  359.795102
# 25%     373.001701    1.085523   373.016258    1.016582  374.129292
# 50%     380.102616    2.384334   380.101303    2.246497  380.973091
# 75%     388.480984    4.956735   388.505367    4.645716  389.003091
# max     411.345970   20.960630   411.360294   19.351218  411.014925
#
#         CO242.std  CO2504.mean  CO2504.std   Glob.mean    Glob.std  ...  \
# count  458.000000   458.000000  458.000000  458.000000  458.000000  ...
# mean     4.290148   380.913345    3.094905  193.287920  145.571635  ...
# std      4.290241    10.900973    2.918037  126.058537   94.362871  ...
# min      0.152663   356.841429    0.037417    3.719434    1.997962  ...
# 25%      1.222415   372.921420    1.004862   71.773357   54.867997  ...
# 50%      2.714247   380.113959    2.137779  197.939217  156.529795  ...
# 75%      6.286882   388.296775    4.376801  304.162015  230.776779  ...
# max     27.656008   411.348676   17.384845  449.450545  309.124047  ...
#
#         T672.mean    T672.std    T84.mean     T84.std   UV_A.mean    UV_A.std  \
# count  458.000000  458.000000  458.000000  458.000000  458.000000  458.000000
# mean     6.311782    1.652786    6.898868    1.987094   10.961236    7.845917
# std      9.680534    0.972092    9.744430    1.172087    6.633754    5.042478
# min    -23.288234    0.066700  -22.659083    0.069879    0.295780    0.174813
# 25%     -1.298557    0.833480   -0.661579    0.888506    4.937496    2.890366
# 50%      7.320084    1.696258    7.917160    2.027125   11.702413    8.390743
# 75%     13.964999    2.359977   14.549644    2.878753   16.727710   12.289556
# max     25.684185    5.124718   25.897075    5.422549   22.560576   16.692785
#
#         UV_B.mean    UV_B.std     CS.mean      CS.std
# count  458.000000  458.000000  458.000000  458.000000
# mean     0.451261    0.391348    0.003050    0.000659
# std      0.319151    0.289645    0.002257    0.000572
# min      0.005346    0.003261    0.000227    0.000027
# 25%      0.137491    0.103036    0.001500    0.000275
# 50%      0.438305    0.391399    0.002475    0.000491
# 75%      0.700794    0.623115    0.004176    0.000829
# max      1.242857    1.074115    0.019094    0.003658
#
# [8 rows x 100 columns]

# %% [markdown]
# ii)

# %%
plt.clf() 
sns.pairplot(npf,hue="class4",vars=npf.columns[1:11],kind="reg") 
plt.show()

# %% [markdown]
# iii)

# %%
plt.clf() 
npf.boxplot(column="RHIRGA84.mean",by="class4") 
plt.show()

# %% [markdown]
# iv)

# %%
class2 = np.array(["event"]*npf.shape[0],dtype="object") 
class2[npf["class4"]=="nonevent"] = "nonevent" 
npf["class2"] = class2
npf["class2"] = npf["class2"].astype("category")

# %%
print(sum(npf['class2'] == 'event'))
# Out:
# 229

# %%
plt.clf() 
npf.boxplot(column="CS.mean",by="class2") 
plt.show()

# %%
npf.describe(include="all")
# Out:
#           class4  CO2168.mean  CO2168.std  CO2336.mean  CO2336.std  \
# count        458   458.000000  458.000000   458.000000  458.000000
# unique         4          NaN         NaN          NaN         NaN
# top     nonevent          NaN         NaN          NaN         NaN
# freq         229          NaN         NaN          NaN         NaN
# mean         NaN   380.996307    3.509202   381.014152    3.295570
# std          NaN    10.897068    3.433711    10.878318    3.192464
# min          NaN   356.526871    0.053968   356.796486    0.048990
# 25%          NaN   373.001701    1.085523   373.016258    1.016582
# 50%          NaN   380.102616    2.384334   380.101303    2.246497
# 75%          NaN   388.480984    4.956735   388.505367    4.645716
# max          NaN   411.345970   20.960630   411.360294   19.351218
#
#         CO242.mean   CO242.std  CO2504.mean  CO2504.std   Glob.mean  ...  \
# count   458.000000  458.000000   458.000000  458.000000  458.000000  ...
# unique         NaN         NaN          NaN         NaN         NaN  ...
# top            NaN         NaN          NaN         NaN         NaN  ...
# freq           NaN         NaN          NaN         NaN         NaN  ...
# mean    381.906526    4.290148   380.913345    3.094905  193.287920  ...
# std      10.482752    4.290241    10.900973    2.918037  126.058537  ...
# min     359.795102    0.152663   356.841429    0.037417    3.719434  ...
# 25%     374.129292    1.222415   372.921420    1.004862   71.773357  ...
# 50%     380.973091    2.714247   380.113959    2.137779  197.939217  ...
# 75%     389.003091    6.286882   388.296775    4.376801  304.162015  ...
# max     411.014925   27.656008   411.348676   17.384845  449.450545  ...
#
#           T672.std    T84.mean     T84.std   UV_A.mean    UV_A.std  \
# count   458.000000  458.000000  458.000000  458.000000  458.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# mean      1.652786    6.898868    1.987094   10.961236    7.845917
# std       0.972092    9.744430    1.172087    6.633754    5.042478
# min       0.066700  -22.659083    0.069879    0.295780    0.174813
# 25%       0.833480   -0.661579    0.888506    4.937496    2.890366
# 50%       1.696258    7.917160    2.027125   11.702413    8.390743
# 75%       2.359977   14.549644    2.878753   16.727710   12.289556
# max       5.124718   25.897075    5.422549   22.560576   16.692785
#
#          UV_B.mean    UV_B.std     CS.mean      CS.std  class2
# count   458.000000  458.000000  458.000000  458.000000     458
# unique         NaN         NaN         NaN         NaN       2
# top            NaN         NaN         NaN         NaN   event
# freq           NaN         NaN         NaN         NaN     229
# mean      0.451261    0.391348    0.003050    0.000659     NaN
# std       0.319151    0.289645    0.002257    0.000572     NaN
# min       0.005346    0.003261    0.000227    0.000027     NaN
# 25%       0.137491    0.103036    0.001500    0.000275     NaN
# 50%       0.438305    0.391399    0.002475    0.000491     NaN
# 75%       0.700794    0.623115    0.004176    0.000829     NaN
# max       1.242857    1.074115    0.019094    0.003658     NaN
#
# [11 rows x 102 columns]

# %% [markdown]
# v)

# %%
npf.hist(column="CO2168.mean",by="class2")
# Out:
# array([<AxesSubplot:title={'center':'event'}>,
#        <AxesSubplot:title={'center':'nonevent'}>], dtype=object)

# %%
npf.hist(column="CO2336.std",by="class2")
# Out:
# array([<AxesSubplot:title={'center':'event'}>,
#        <AxesSubplot:title={'center':'nonevent'}>], dtype=object)

# %% [markdown]
# vi)

# %%
npf.hist(column="UV_A.mean",by="class2")
# Out:
# array([<AxesSubplot:title={'center':'event'}>,
#        <AxesSubplot:title={'center':'nonevent'}>], dtype=object)

# %% [markdown]
# More UV_A on "event" days!

# %%
npf.hist(column="UV_B.mean",by="class2")
# Out:
# array([<AxesSubplot:title={'center':'event'}>,
#        <AxesSubplot:title={'center':'nonevent'}>], dtype=object)

# %% [markdown]
# More UV_B on "event" days!

# %% [markdown]
# Problem 2

# %% [markdown]
# Task A)

# %%
def f(x):
    return (1 + 𝑥) - ((𝑥**2)/2)

def sample_pairs(n=1):
    x_arr = []
    y_arr = []
    for i in range(n):
        x = np.random.uniform(low=-3.0, high=3.0)
        epsilon = np.random.normal(0, 0.4, 1)
        y = f(x) + epsilon[0]
        x_arr.append(x)
        y_arr.append(y)
    return np.array([x_arr, y_arr])

plot = sample_pairs(100)
training = sample_pairs(20)
validation = sample_pairs(20)
test = sample_pairs(1000)

# %% [markdown]
# Task B)

# %%
from matplotlib.pyplot import figure
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error
import operator


figure(figsize=(10, 10), dpi=500)

# tr = training
x_tr = training[0][:,np.newaxis]
y_tr = training[1][:,np.newaxis]

x_val = validation[0][:,np.newaxis]
y_val = validation[1][:,np.newaxis]

x_test = test[0][:,np.newaxis]
y_test = test[1][:,np.newaxis]

x_plot = plot[0][:,np.newaxis]

mse_tr = []
mse_val = []
mse_test = []

for degree in range(0,11):
    polynomial_features= PolynomialFeatures(degree=degree)
    
    x_poly_tr = polynomial_features.fit_transform(x_tr)
    x_poly_plot = polynomial_features.fit_transform(x_plot)
    
    x_poly_val = polynomial_features.fit_transform(x_tr)
    x_poly_test = polynomial_features.fit_transform(x_test)

    model = LinearRegression()
    model.fit(x_poly_tr, y_tr)
    
    y_poly_pred_tr = model.predict(x_poly_tr)
    y_poly_pred_val = model.predict(x_poly_val)
    y_poly_pred_test = model.predict(x_poly_test)
    
    y_poly_pred_plot = model.predict(x_poly_plot)

    mse_tr.append(mean_squared_error(y_tr,y_poly_pred_tr))
    mse_val.append(mean_squared_error(y_val,y_poly_pred_val))
    mse_test.append(mean_squared_error(y_test,y_poly_pred_test))


    plt.scatter(x_tr, y_tr, s=10)
    # sort the values of x before line plot
    sort_axis = operator.itemgetter(0)
    sorted_zip = sorted(zip(x_plot ,y_poly_pred_plot), key=sort_axis)
    x, y = zip(*sorted_zip)
    plt.plot(x, y)

plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-510-3490d9ebd3d0> in <module>
# ----> 1 plot_polynomials = [sample_fitted_ploynomial(training, p, x_samples_plot) for p in range(6, 11)]
#       2
#       3 figure(figsize=(10, 5), dpi=500)
#       4
#       5 plt.scatter(x, y)
#
# <ipython-input-510-3490d9ebd3d0> in <listcomp>(.0)
# ----> 1 plot_polynomials = [sample_fitted_ploynomial(training, p, x_samples_plot) for p in range(6, 11)]
#       2
#       3 figure(figsize=(10, 5), dpi=500)
#       4
#       5 plt.scatter(x, y)
#
# <ipython-input-453-4d96c0498312> in sample_fitted_ploynomial(training, p, x_samples)
#      11
#      12 def sample_fitted_ploynomial(training, p, x_samples):
# ---> 13     x, y = zip(*training)
#      14     w = np.polynomial.polynomial.Polynomial.fit(x, y, p)
#      15     y_samples = [y_hat(w ,x) for x in x_samples]
#
# ValueError: too many values to unpack (expected 2)

# %%
mse_data = np.column_stack([range(0,11), mse_tr])

mses = pd.DataFrame(data=mse_data, columns=['degree', 'mse_tr'], dtype="object")

mses
# Out:
#    degree    mse_tr
# 0     0.0  7.632317
# 1     1.0   1.63695
# 2     2.0  0.109555
# 3     3.0  0.102724
# 4     4.0  0.098318
# 5     5.0  0.098209
# 6     6.0  0.098196
# 7     7.0   0.08893
# 8     8.0  0.083261
# 9     9.0  0.082508
# 10   10.0  0.045013

# %% [markdown]
# Task C)

# %%
mses['mse_val'] = mse_val
mses['mse_val'] = mses['mse_val'].astype("object")
mses['mse_test'] = mse_test
mses['mse_test'] = mses['mse_test'].astype("object")

mses
# Out:
#    degree    mse_tr    mse_val   mse_test
# 0     0.0  7.632317   3.389554    4.81479
# 1     1.0   1.63695  11.615377   2.379781
# 2     2.0  0.109555  12.511093   0.203045
# 3     3.0  0.102724  12.453766   0.187765
# 4     4.0  0.098318  12.340284   0.213755
# 5     5.0  0.098209  12.336318   0.215764
# 6     6.0  0.098196  12.333658   0.216473
# 7     7.0   0.08893  12.375896   0.278861
# 8     8.0  0.083261  12.497468   0.519139
# 9     9.0  0.082508  12.489696   0.308607
# 10   10.0  0.045013  12.729403  83.196503

# %% [markdown]
# Task D)

# %%
from sklearn.model_selection import KFold

# COPY **

figure(figsize=(10, 5), dpi=500)

# tr = training


x_comb = np.concatenate((training[0], validation[0]), axis=None)[:,np.newaxis]
y_comb = np.concatenate((training[1], validation[1]), axis=None)[:,np.newaxis]

# print(x_comb)

mse_kfold = []

kf = KFold(n_splits=10)

for degree in range(0,11):
    splits_mse = []
    for test, train in kf.split(list(zip(x_comb, y_comb))):
        x_comb_tr = [x_comb[i] for i in train]
        y_comb_tr = [x_comb[i] for i in train]
        
        x_comb_test = [x_comb[i] for i in test]
        y_comb_test = [x_comb[i] for i in test]
                        
        polynomial_features= PolynomialFeatures(degree=degree)
    
        x_poly_comb_tr = polynomial_features.fit_transform(x_comb_tr)
        x_poly_comb_test = polynomial_features.fit_transform(x_comb_test)
        
        model = LinearRegression()
        model.fit(x_poly_comb_tr, y_comb_tr)
            
        y_poly_comb_pred = model.predict(x_poly_comb_test)
                
        splits_mse.append(mean_squared_error(y_comb_test, y_poly_comb_pred))
    mse_kfold.append(np.average(splits_mse))
    
mses['mse_kfold'] = mse_kfold
mses['mse_kfold'] = mses['mse_kfold'].astype("object")
mses
# Out:
#    degree    mse_tr    mse_val   mse_test      mse_kfold
# 0     0.0  7.632317   3.389554    4.81479       3.989433
# 1     1.0   1.63695  11.615377   2.379781            0.0
# 2     2.0  0.109555  12.511093   0.203045            0.0
# 3     3.0  0.102724  12.453766   0.187765            0.0
# 4     4.0  0.098318  12.340284   0.213755        6.43157
# 5     5.0  0.098209  12.336318   0.215764       5.378584
# 6     6.0  0.098196  12.333658   0.216473     179.605924
# 7     7.0   0.08893  12.375896   0.278861     201.327094
# 8     8.0  0.083261  12.497468   0.519139    5499.455207
# 9     9.0  0.082508  12.489696   0.308607    6917.780767
# 10   10.0  0.045013  12.729403  83.196503  186584.214111

# %% [markdown]
# Task E

# %%
from sklearn.model_selection import KFold

figure(figsize=(10, 5), dpi=500)

mse_comb = []

for degree in range(0,11):
    polynomial_features= PolynomialFeatures(degree=degree)
    
    x_poly_comb = polynomial_features.fit_transform(x_comb)
    x_poly_test = polynomial_features.fit_transform(x_test)
        
    model = LinearRegression()
    model.fit(x_poly_comb, y_comb)
            
    y_poly_test_pred = model.predict(x_poly_test)
                
    mse_comb.append(mean_squared_error(y_test, y_poly_test_pred))
    
mses['mse_comb'] = mse_comb
mses['mse_comb'] = mses['mse_comb'].astype("object")
mses
# Out:
#    degree    mse_tr    mse_val   mse_test      mse_kfold  mse_comb
# 0     0.0  7.632317   3.389554    4.81479       3.989433  4.729691
# 1     1.0   1.63695  11.615377   2.379781            0.0  1.983862
# 2     2.0  0.109555  12.511093   0.203045            0.0  0.160203
# 3     3.0  0.102724  12.453766   0.187765            0.0  0.160319
# 4     4.0  0.098318  12.340284   0.213755        6.43157  0.160669
# 5     5.0  0.098209  12.336318   0.215764       5.378584  0.192606
# 6     6.0  0.098196  12.333658   0.216473     179.605924    0.1778
# 7     7.0   0.08893  12.375896   0.278861     201.327094   0.18047
# 8     8.0  0.083261  12.497468   0.519139    5499.455207  0.177401
# 9     9.0  0.082508  12.489696   0.308607    6917.780767  0.721048
# 10   10.0  0.045013  12.729403  83.196503  186584.214111  0.629633

# %% [markdown]
# Task F: Assuming my table is right, I would choose 2 or 3 degree polynomial for OLS regression.

# %% [markdown]
# Problem 3

# %% [markdown]
# Task A & B) Selected regression model LassoLars

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LassoLars

data_p3 = pd.read_csv('Bias_correction_ucl.csv')
data_p3 = data_p3.dropna() 
data_p3 = data_p3.drop("station",axis=1)
data_p3 = data_p3.drop("Date",axis=1)
data_p3 = data_p3.drop("Next_Tmin",axis=1)

X_p3 = data_p3.sample(500)
Y_p3 = X_p3['Next_Tmax']

X_p3 = X_p3.drop('Next_Tmax',axis=1)

X_p3_train, X_p3_test, Y_p3_train, Y_p3_test = train_test_split(X_p3, Y_p3, test_size = 0.8)

Y_p3_train.describe()

LR = LinearRegression()
LR.fit(X_p3_train, Y_p3_train)

RT = DecisionTreeRegressor(random_state=0)
RT.fit(X_p3_train, Y_p3_train)

RFR = RandomForestRegressor(max_depth=2, random_state=0)
RFR.fit(X_p3_train, Y_p3_train)

SVR = SVR(C=1.0, epsilon=0.2)
SVR.fit(X_p3_train, Y_p3_train)

LL = LassoLars(alpha=0.01, normalize=False)
LL.fit(X_p3_train, Y_p3_train)

Y_lr_prediction = LR.predict(X_p3_test)
Y_rt_prediction = RT.predict(X_p3_test)
Y_rfr_prediction = RFR.predict(X_p3_test)
Y_svr_prediction = SVR.predict(X_p3_test)
Y_ll_prediction = LL.predict(X_p3_test)

Y_lr_prediction_tr = LR.predict(X_p3_train)
Y_rt_prediction_tr = RT.predict(X_p3_train)
Y_rfr_prediction_tr = RFR.predict(X_p3_train)
Y_svr_prediction_tr = SVR.predict(X_p3_train)
Y_ll_prediction_tr = LL.predict(X_p3_train)


rmse_lr_test = np.sqrt(mean_squared_error(Y_p3_test, Y_lr_prediction))
rmse_rt_test = np.sqrt(mean_squared_error(Y_p3_test, Y_rt_prediction))
rmse_clf_test = np.sqrt(mean_squared_error(Y_p3_test, Y_rfr_prediction))
rmse_svr_test = np.sqrt(mean_squared_error(Y_p3_test, Y_svr_prediction))
rmse_ll_test = np.sqrt(mean_squared_error(Y_p3_test, Y_ll_prediction))

rmse_lr_tr = np.sqrt(mean_squared_error(Y_p3_train, Y_lr_prediction_tr))
rmse_rt_tr = np.sqrt(mean_squared_error(Y_p3_train, Y_rt_prediction_tr))
rmse_clf_tr = np.sqrt(mean_squared_error(Y_p3_train, Y_rfr_prediction_tr))
rmse_svr_tr = np.sqrt(mean_squared_error(Y_p3_train, Y_svr_prediction_tr))
rmse_ll_tr = np.sqrt(mean_squared_error(Y_p3_train, Y_ll_prediction_tr))

rmses_test = np.column_stack([['rmse_test'] ,rmse_lr_test, rmse_rt_test, rmse_clf_test, rmse_svr_test, rmse_ll_test])
rmses_tr = np.column_stack([['rmse_tr'] ,rmse_lr_tr, rmse_rt_tr, rmse_clf_tr, rmse_svr_tr, rmse_ll_tr])

df_test = pd.DataFrame(data=rmses_test, columns=cols, dtype="object")
df_tr = pd.DataFrame(data=rmses_tr, columns=cols, dtype="object")

df3 = pd.concat([df_test, df_tr], ignore_index = True)

df3
# Out:
#       metric   linear regression    regression tree       random forest  \
# 0  rmse_test  1.6834496108218413  2.540959464454323  1.7381935050582147
# 1    rmse_tr  1.5232276833497187                0.0  1.6927309003186828
#
#   support vector machine          lasso lars
# 0      2.996758819244152   1.661083190628328
# 1     3.3509814149967245  1.5445417197701465

# %% [markdown]
# On the training set RandomForestRegressor produces zero RMSE. If I am right, it is also the most complex model as the difference between rmse_tr and rmse_test is the largest. It has no error on the training set but produces some error on the test set. Best performing models seems to be good old Linear Regression. Results of the LassoLars is very similar because they actually almost the same algorithm (with alpha = 1 they would actually be the same).

# %% [markdown]
# Task C)

# %%
mse_comb = []

kf = KFold(n_splits=10)

for test, train in kf.split(list(zip(X_p3_train.iloc, Y_p3_train.iloc))):
        
    X_p3_kfold_train = [X_p3_train.iloc[i] for i in train]
    Y_p3_kfold_train = [Y_p3_train.iloc[i] for i in train]
        
    X_p3_kfold_test = [X_p3_train.iloc[i] for i in test]
    Y_p3_kfold_test = [Y_p3_train.iloc[i] for i in test]
                                    
    model = LinearRegression()
    model.fit(x_poly_comb_tr, y_comb_tr)
            
    y_poly_comb_pred = model.predict(x_poly_comb_test)
                
    LR = LinearRegression()
    LR.fit(X_p3_kfold_train, Y_p3_kfold_train)

    RT = DecisionTreeRegressor(random_state=0)
    RT.fit(X_p3_kfold_train, Y_p3_kfold_train)

    RFR = RandomForestRegressor(max_depth=2, random_state=0)
    RFR.fit(X_p3_kfold_train, Y_p3_kfold_train)

    # SVR = SVR(C=1.0, epsilon=0.2)
    SVR.fit(X_p3_kfold_train, Y_p3_kfold_train)

    LL = LassoLars(alpha=0.01, normalize=False)
    LL.fit(X_p3_kfold_train, Y_p3_kfold_train)

    Y_lr_prediction = LR.predict(X_p3_test)
    Y_rt_prediction = RT.predict(X_p3_test)
    Y_rfr_prediction = RFR.predict(X_p3_test)
    Y_svr_prediction = SVR.predict(X_p3_test)
    Y_ll_prediction = LL.predict(X_p3_test)

    Y_lr_prediction_tr = LR.predict(X_p3_train)
    Y_rt_prediction_tr = RT.predict(X_p3_train)
    Y_rfr_prediction_tr = RFR.predict(X_p3_train)
    Y_svr_prediction_tr = SVR.predict(X_p3_train)
    Y_ll_prediction_tr = LL.predict(X_p3_train)


    rmse_lr_test = np.sqrt(mean_squared_error(Y_p3_test, Y_lr_prediction))
    rmse_rt_test = np.sqrt(mean_squared_error(Y_p3_test, Y_rt_prediction))
    rmse_clf_test = np.sqrt(mean_squared_error(Y_p3_test, Y_rfr_prediction))
    rmse_svr_test = np.sqrt(mean_squared_error(Y_p3_test, Y_svr_prediction))
    rmse_ll_test = np.sqrt(mean_squared_error(Y_p3_test, Y_ll_prediction))
